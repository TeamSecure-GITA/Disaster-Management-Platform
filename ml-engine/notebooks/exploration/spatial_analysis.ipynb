# %% [markdown]
# # Geospatial Clustering & Proximity Analysis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.feature_engineering.spatial import SpatialFeatureExtractor
df = pd.read_csv("../../datasets/raw/weather/sample_weather.csv")
ext = SpatialFeatureExtractor()
df_spatial = ext.transform(df)
print(df_spatial[["latitude", "longitude", "geo_x", "geo_y", "geo_z"]].head())
