# %% [markdown]
# # Cross-Hazard Correlation Analysis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
df = pd.read_csv("../../datasets/test/landslide/test_landslide.csv")
corr = df.corr()
print("Top correlations with landslide_occurred:")
print(corr["landslide_occurred"].sort_values(ascending=False))
