# %% [markdown]
# # Telemetry & Sensor Data Overview
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
import sys
from pathlib import Path
sys.path.insert(0, str(Path("../..").resolve()))

df_weather = pd.read_csv("../../datasets/raw/weather/sample_weather.csv")
print("Weather Shape:", df_weather.shape)
df_weather.head()
