# %% [markdown]
# # IoT Sensor Glitch & Telemetry EDA
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
df = pd.read_csv("../../datasets/test/anomaly/test_anomaly.csv")
print("Sensor Anomaly Distribution:")
print(df["is_anomaly"].value_counts(normalize=True))
