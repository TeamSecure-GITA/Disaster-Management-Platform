# %% [markdown]
# # Contamination & False Alarm Threshold Calibration
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import numpy as np
from src.evaluation.anomaly import AnomalyEvaluator
scores = np.random.uniform(0, 1, 100)
labels = np.random.choice([0, 1], p=[0.9, 0.1], size=100)
eval_res = AnomalyEvaluator.evaluate(labels, scores, threshold=0.85)
print("Threshold Evaluation:", eval_res)
