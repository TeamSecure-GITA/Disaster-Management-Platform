# %% [markdown]
# # Unsupervised Sensor Outlier Detection
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.training.anomaly_trainer import AnomalyTrainer
df = pd.read_csv("../../datasets/test/anomaly/test_anomaly.csv")
trainer = AnomalyTrainer()
res = trainer.train(df)
print("Detection Results:", res)
