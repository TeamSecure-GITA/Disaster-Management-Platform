# %% [markdown]
# # Weather Temperature & Humidity Prognosis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.feature_engineering.weather import WeatherFeatureExtractor
df = pd.read_csv("../../datasets/raw/weather/sample_weather.csv")
ext = WeatherFeatureExtractor()
df_w = ext.transform(df)
print("Dew Point & Vapor Pressure Deficit:")
print(df_w[["dew_point_c", "vapor_pressure_deficit_kpa", "wind_u", "wind_v"]].head())
