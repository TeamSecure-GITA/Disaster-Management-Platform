# %% [markdown]
# # Sequential Rainfall Forecasting
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.training.forecasting_trainer import ForecastingTrainer
df = pd.read_csv("../../datasets/test/forecasting/test_forecasting.csv")
trainer = ForecastingTrainer()
metrics = trainer.train(df)
print("Forecasting Accuracy (RMSE/MAE):", metrics)
