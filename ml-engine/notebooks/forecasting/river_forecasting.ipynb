# %% [markdown]
# # River Stage Hydrologic Forecast
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.evaluation.forecasting import ForecastingEvaluator
evaluator = ForecastingEvaluator()
res = evaluator.evaluate([3.2, 4.5, 6.1, 8.0], [3.1, 4.7, 5.9, 7.8])
print("Hydrologic Verification:", res)
