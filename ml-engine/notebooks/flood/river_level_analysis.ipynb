# %% [markdown]
# # River Stage & Discharge Hydrograph Analysis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
df = pd.read_csv("../../datasets/raw/river/sample_river.csv")
print("River Stage Statistics:")
print(df[["water_level", "flow_rate", "discharge"]].describe())
