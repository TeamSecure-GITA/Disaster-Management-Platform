# %% [markdown]
# # Flood Catchment Telemetry Exploratory Analysis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
df = pd.read_csv("../../datasets/test/flood/test_flood.csv")
print("Flood Dataset Summary:")
print(df.info())
