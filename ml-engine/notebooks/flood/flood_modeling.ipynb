# %% [markdown]
# # Riverine Flood Stage Classification & Inundation Risk
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.training.flood_trainer import FloodTrainer
df = pd.read_csv("../../datasets/test/flood/test_flood.csv")
trainer = FloodTrainer()
metrics = trainer.train(df)
print("Flood Model Metrics:", metrics)
