# %% [markdown]
# # Catchment Precipitation Accumulation Dynamics
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.feature_engineering.rainfall import RainfallFeatureExtractor
df = pd.read_csv("../../datasets/raw/rainfall/sample_rainfall.csv")
ext = RainfallFeatureExtractor()
df_r = ext.transform(df)
print(df_r[["rainfall_mm", "rain_rolling_6h", "antecedent_precipitation_index"]].head())
