# %% [markdown]
# # Landslide Model Evaluation & Hazard Verification
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.evaluation.hazard_metrics import HazardMetrics
metrics = HazardMetrics.evaluate_warnings(
    y_true=[0, 1, 0, 1, 1], y_pred=[0, 1, 0, 0, 1]
)
print("Early Warning Verification Metrics:", metrics)
