# %% [markdown]
# # Landslide Hazard Classification Training
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.training.landslide_trainer import LandslideTrainer
df = pd.read_csv("../../datasets/test/landslide/test_landslide.csv")
trainer = LandslideTrainer()
metrics = trainer.train(df)
print("Training Metrics:", metrics)
