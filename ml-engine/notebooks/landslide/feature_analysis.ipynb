# %% [markdown]
# # Geotechnical & Hydrological Feature Analysis
# Disaster Management Platform - Machine Learning & Statistical Modeling Suite.

# %%
import pandas as pd
from src.feature_engineering.geotechnical import GeotechnicalFeatureExtractor
df = pd.read_csv("../../datasets/raw/geotechnical/sample_geotechnical.csv")
ext = GeotechnicalFeatureExtractor()
df_feats = ext.transform(df)
print(df_feats.head())
